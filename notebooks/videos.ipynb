# %% [markdown]
# ## Videos

# %% [markdown]
# #### Config

# %%
## packages
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('metropolis')
SAVE = True

## toolkit
from src.triangulations import tri_circle, tri_rectangle, tri_maze, tri_sphere, tri_torus
from src.fem import build_matricies, solve_fem

## config
tmax = 100
dt = 0.01
triN = 16
L = 10
np.random.seed(0)

# %% [markdown]
# #### PDE

# %%
## pde config
N = 2
gamma = np.array([1, 0.02])
k1 = 9
k2 = 11
r = lambda u: np.column_stack((
        k1 * (u[:, 1] - u[:, 0] * u[:, 1] / (1 + u[:, 1]**2)),
        k2 - u[:, 1] - 4 * u[:, 0] * u[:, 1] / (1 + u[:, 1]**2),
    ))

# %% [markdown]
# #### Square Solution

# %%
## triangulate the domain
pts, tris = tri_rectangle(L, L, triN)
damp_mat, stiff_mat = build_matricies(pts, tris)
n_pts = len(pts)

## solve the system
u0 = np.random.uniform(-1, 1, (n_pts, N))

## plot it
fig, axs = plt.subplots(1, 3)
fig.set_figwidth(4)
fig.set_figheight(2)
for ax in axs:
    ax.set_axis_off()
    ax.axis('equal')

# t = 0
axs[0].set_title('$t = 0$')
axs[0].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u0[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

# t = 10
u = solve_fem(r, gamma, 10, dt, u0, damp_mat, stiff_mat)
axs[1].set_title('$t = 10$')
axs[1].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

# t = 100
u = solve_fem(r, gamma, tmax, dt, u0, damp_mat, stiff_mat)
axs[2].set_title(f'$t = {tmax:,}$')
axs[2].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

## final things
fig.tight_layout()
if SAVE: fig.savefig('presentation/figures/square.pdf', bbox_inches='tight')

## memory
del pts, tris, n_pts, stiff_mat, damp_mat, u0, u, fig, axs

# %% [markdown]
# #### Circles

# %%
## triangulate the domain
pts, tris = tri_circle(L / 2, triN)
damp_mat, stiff_mat = build_matricies(pts, tris)
n_pts = len(pts)

## solve the system
u0 = np.random.uniform(-1, 1, (n_pts, N))

## plot it
fig, axs = plt.subplots(1, 3)
fig.set_figwidth(4)
fig.set_figheight(2)
for ax in axs:
    ax.set_axis_off()
    ax.axis('equal')

# t = 0
axs[0].set_title('$t = 0$')
axs[0].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u0[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

# t = 10
u = solve_fem(r, gamma, 10, dt, u0, damp_mat, stiff_mat)
axs[1].set_title('$t = 10$')
axs[1].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

# t = 100
u = solve_fem(r, gamma, tmax, dt, u0, damp_mat, stiff_mat)
axs[2].set_title(f'$t = {tmax:,}$')
axs[2].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

## final things
fig.tight_layout()
if SAVE: fig.savefig('presentation/figures/circle.pdf', bbox_inches='tight')

## memory
del pts, tris, n_pts, stiff_mat, damp_mat, u0, u, fig, axs

# %% [markdown]
# #### Maze

# %%
## triangulate the domain
mn = 10
pts, tris = tri_maze(mn, mn, L / (2 * mn - 1), triN)
damp_mat, stiff_mat = build_matricies(pts, tris)
n_pts = len(pts)

## solve the system
u0 = np.random.uniform(-1, 1, (n_pts, N))

## plot it
fig, axs = plt.subplots(1, 3)
fig.set_figwidth(4)
fig.set_figheight(2)
for ax in axs:
    ax.set_axis_off()
    ax.axis('equal')

# t = 0
axs[0].set_title('$t = 0$')
axs[0].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u0[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

# t = 10
u = solve_fem(r, gamma, 10, dt, u0, damp_mat, stiff_mat)
axs[1].set_title('$t = 10$')
axs[1].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

# t = 100
u = solve_fem(r, gamma, tmax, dt, u0, damp_mat, stiff_mat)
axs[2].set_title(f'$t = {tmax:,}$')
axs[2].tripcolor(
        pts[:, 0],
        pts[:, 1],
        u[:, 0],
        triangles=tris,
        cmap='viridis',
        shading='gouraud',
    )

## final things
fig.tight_layout()
if SAVE: fig.savefig('presentation/figures/maze.pdf', bbox_inches='tight')

## memory
del pts, tris, n_pts, stiff_mat, damp_mat, u0, u, fig, axs

# %% [markdown]
# #### Circle

# %%
## triangulate the domain
pts, tris = tri_sphere(L / 2, 5)
damp_mat, stiff_mat = build_matricies(pts, tris)
n_pts = len(pts)

## solve the system
u0 = np.random.uniform(-1, 1, (n_pts, N))

## plot it
fig, axs = plt.subplots(1, 3, subplot_kw={'projection': '3d'})
fig.set_figwidth(4)
fig.set_figheight(2)
for ax in axs:
    ax.set_axis_off()
    ax.axis('equal')

# t = 0
axs[0].set_title('$t = 0$')
tri_cols = u0[:, 0][tris].mean(axis=1)
color = (tri_cols - tri_cols.min()) / (tri_cols.max() - tri_cols.min())
mesh = Poly3DCollection(
        pts[tris],
        facecolors=plt.cm.viridis(color),
    )
axs[0].add_collection3d(mesh)

# t = 10
u = solve_fem(r, gamma, 10, dt, u0, damp_mat, stiff_mat)
axs[1].set_title('$t = 10$')
tri_cols = u[:, 0][tris].mean(axis=1)
color = (tri_cols - tri_cols.min()) / (tri_cols.max() - tri_cols.min())
mesh = Poly3DCollection(
        pts[tris],
        facecolors=plt.cm.viridis(color),
    )
axs[1].add_collection3d(mesh)

# t = 1000
u = solve_fem(r, gamma, tmax, dt, u0, damp_mat, stiff_mat)
axs[2].set_title(f'$t = {tmax:,}$')
tri_cols = u[:, 0][tris].mean(axis=1)
color = (tri_cols - tri_cols.min()) / (tri_cols.max() - tri_cols.min())
mesh = Poly3DCollection(
        pts[tris],
        facecolors=plt.cm.viridis(color),
    )
axs[2].add_collection3d(mesh)

## final things
for ax in axs:
    ax.set_facecolor(fig.get_facecolor())
    ax.set_xlim([x / 1.5 for x in ax.get_xlim()])
    ax.set_ylim([x / 1.5 for x in ax.get_ylim()])
    ax.set_zlim([x / 1.5 for x in ax.get_zlim()])
fig.tight_layout()
if SAVE: fig.savefig('presentation/figures/sphere.pdf', bbox_inches='tight')

## memory
del pts, tris, n_pts, stiff_mat, damp_mat, u0, u, fig, axs

# %% [markdown]
# #### Torus

# %%
## triangulate the domain
pts, tris = tri_torus(1.5, L / 2 - 1.5, triN)
damp_mat, stiff_mat = build_matricies(pts, tris)
n_pts = len(pts)

## solve the system
u0 = np.random.uniform(-1, 1, (n_pts, N))

## plot it
fig, axs = plt.subplots(1, 3, subplot_kw={'projection': '3d'})
fig.set_figwidth(4)
fig.set_figheight(2)
for ax in axs:
    ax.set_axis_off()
    ax.axis('equal')

# t = 0
axs[0].set_title('$t = 0$')
tri_cols = u0[:, 0][tris].mean(axis=1)
color = (tri_cols - tri_cols.min()) / (tri_cols.max() - tri_cols.min())
mesh = Poly3DCollection(
        pts[tris],
        facecolors=plt.cm.viridis(color),
    )
axs[0].add_collection3d(mesh)

# t = 10
u = solve_fem(r, gamma, 10, dt, u0, damp_mat, stiff_mat)
axs[1].set_title('$t = 10$')
tri_cols = u[:, 0][tris].mean(axis=1)
color = (tri_cols - tri_cols.min()) / (tri_cols.max() - tri_cols.min())
mesh = Poly3DCollection(
        pts[tris],
        facecolors=plt.cm.viridis(color),
    )
axs[1].add_collection3d(mesh)

# t = 1000
u = solve_fem(r, gamma, tmax, dt, u0, damp_mat, stiff_mat)
axs[2].set_title(f'$t = {tmax:,}$')
tri_cols = u[:, 0][tris].mean(axis=1)
color = (tri_cols - tri_cols.min()) / (tri_cols.max() - tri_cols.min())
mesh = Poly3DCollection(
        pts[tris],
        facecolors=plt.cm.viridis(color),
    )
axs[2].add_collection3d(mesh)

## final things
for ax in axs:
    ax.set_facecolor(fig.get_facecolor())
    ax.set_xlim([x / 1.5 for x in ax.get_xlim()])
    ax.set_ylim([x / 1.5 for x in ax.get_ylim()])
    ax.set_zlim(ax.get_xlim())
fig.tight_layout()
if SAVE: fig.savefig('presentation/figures/torus.pdf', bbox_inches='tight')

## memory
del pts, tris, n_pts, stiff_mat, damp_mat, u0, u, fig, axs
